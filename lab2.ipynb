# %% [markdown]
# # Name: Ziling Huang
# # username: zhu51

# %%
# start the Spark context
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install -q pyspark


import os
os.environ['PYTHONHASHSEED']="0"
os.environ["PYSPARK_PYTHON"]="python3"
os.environ["JAVA_HOME"]="/usr/lib/jvm/java-8-openjdk-amd64/"
# A few additional libraries we will need
from math import sqrt

import pyspark
from pyspark import SparkConf, SparkContext
from pyspark.sql import *

try:
  conf = SparkConf().setMaster("local[*]").set("spark.executor.memory", "1g").set("spark.executorEnv.PYTHONHASHSEED","0").set("spark.ui.port", "4050")
  sc = SparkContext(conf = conf)
  spark = SparkSession.builder.getOrCreate()
except ValueError:
  #it's ok if the server is already started
  pass

def dbg(x):
  """ A helper function to print debugging information on RDDs """
  if isinstance(x, pyspark.RDD):
    print([(t[0], list(t[1]) if 
            isinstance(t[1], pyspark.resultiterable.ResultIterable) else t[1])
           if isinstance(t, tuple) else t
           for t in x.take(100)])
  else:
    print(x)
    

import unittest
Test = unittest.TestCase()
# Out:
#      |████████████████████████████████| 281.4 MB 31 kB/s
#      |████████████████████████████████| 198 kB 44.0 MB/s
#   Building wheel for pyspark (setup.py) ... done

# %%
pair = ('a','b') 
print(pair[0], pair[1])
# Out:
# a b

# %%
#Let’s consider a quick example
pets = sc.parallelize([('cat',1), ('dog',3), ('cat',2),('dog',1),('hamster',1)]) 
dbg(pets.reduceByKey(lambda x,y: x+y))
dbg(pets.groupByKey())
dbg(pets.sortByKey())
# Out:
# [('cat', 3), ('dog', 4), ('hamster', 1)]
# [('cat', [1, 2]), ('dog', [3, 1]), ('hamster', [1])]
# [('cat', 1), ('cat', 2), ('dog', 3), ('dog', 1), ('hamster', 1)]

# %%
#Let’s try for a more complex example, word count and working with files. 
#First use a shell command to download the text of Peter Pan from the Guttenberg project
# !wget -q -O peterpan.txt https://www.gutenberg.org/files/16/16-0.txt
# load the file into a distributed dataset of lines
file = sc.textFile("peterpan.txt")
# split each line into (word, 1) tuples
words = file.flatMap(lambda line: [(word.lower(), 1) for word in line.split(" ")])
# reduce by key (the word) the counts and sort descending
counts = words.reduceByKey(lambda a, b: a + b).sortBy(lambda x: x[1], False) 
dbg(counts.collect())
# Out:
# [('the', 2496), ('', 1965), ('and', 1417), ('to', 1233), ('he', 1029), ('a', 975), ('of', 966), ('was', 904), ('in', 717), ('it', 594), ('that', 581), ('she', 574), ('they', 565), ('had', 504), ('his', 471), ('you', 450), ('but', 442), ('for', 406), ('not', 396), ('her', 370), ('with', 370), ('is', 341), ('at', 336), ('as', 336), ('on', 335), ('i', 253), ('have', 251), ('be', 249), ('were', 243), ('peter', 242), ('all', 237), ('this', 228), ('said', 218), ('their', 217), ('so', 215), ('would', 212), ('wendy', 202), ('by', 191), ('are', 190), ('him', 186), ('one', 178), ('when', 172), ('them', 165), ('if', 160), ('“i', 159), ('there', 154), ('we', 154), ('no', 149), ('from', 147), ('or', 144), ('could', 139), ('been', 135), ('who', 134), ('which', 128), ('what', 124), ('did', 117), ('out', 115), ('up', 115), ('then', 113), ('do', 110), ('said,', 108), ('about', 107), ('an', 103), ('into', 100), ('little', 95), ('hook', 94), ('darling', 94), ('now', 93), ('will', 89), ('see', 88), ('like', 86), ('only', 86), ('project', 83), ('time', 81), ('your', 80), ('children', 78), ('never', 76), ('john', 76), ('just', 74), ('other', 73), ('mrs.', 72), ('any', 72), ('cried', 72), ('came', 71), ('my', 70), ('how', 70), ('thought', 69), ('must', 68), ('michael', 68), ('first', 67), ('very', 66), ('him.', 66), ('know', 65), ('such', 65), ('it,', 63), ('quite', 63), ('knew', 63), ('more', 62), ('way', 61), ('boys', 61), ('than', 60), ('go', 57), ('come', 57), ('it.', 56), ('over', 56), ('course', 55), ('even', 54), ('long', 54), ('don’t', 54), ('still', 54), ('wendy,', 54), ('gutenberg-tm', 54), ('him,', 53), ('always', 51), ('can', 51), ('after', 50), ('down', 50), ('through', 50), ('me', 50), ('peter,', 50), ('last', 49), ('because', 49), ('may', 48), ('think', 48), ('made', 48), ('should', 48), ('went', 48), ('moment', 48), ('though', 47), ('them,', 47), ('let', 47), ('“and', 47), ('where', 46), ('mr.', 46), ('once', 46), ('“it', 46), ('really', 45), ('“you', 45), ('every', 45), ('before', 44), ('round', 44), ('am', 44), ('most', 44), ('heard', 43), ('without', 43), ('cried,', 42), ('her.', 41), ('saw', 41), ('rather', 40), ('put', 40), ('has', 40), ('night', 39), ('again', 39), ('some', 39), ('get', 39), ('two', 38), ('ever', 38), ('tell', 38), ('look', 38), ('found', 38), ('“what', 38), ('her,', 37), ('them.', 37), ('almost', 37), ('pirates', 37), ('gave', 36), ('say', 36), ('work', 36), ('mother', 36), ('looking', 35), ('us', 35), ('upon', 35), ('chapter', 34), ('sat', 34), ('nana', 34), ('while', 34), ('off', 34), ('man', 34), ('too', 34), ('looked', 33), ('got', 33), ('told', 33), ('thing', 33), ('asked', 33), ('now,', 33), ('take', 32), ('hear', 32), ('hand', 32), ('each', 32), ('home', 31), ('under', 31), ('going', 31), ('back', 31), ('away', 30), ('much', 30), ('called', 30), ('fell', 30), ('things', 29), ('these', 29), ('sure', 29), ('wendy’s', 28), ('sometimes', 28), ('sound', 28), ('“the', 28), ('soon', 28), ('many', 28), ('might', 28), ('its', 28), ('want', 28), ('slightly', 28), ('smee', 28), ('give', 27), ('thus', 27), ('make', 27), ('tinker', 27), ('peter.', 27), ('“but', 27), ('said.', 27), ('himself', 27), ('peter’s', 27), ('electronic', 27), ('house', 26), ('good', 26), ('being', 26), ('light', 26), ('our', 26), ('great', 26), ('tink', 26), ('face', 26), ('gutenberg', 25), ('something', 25), ('eyes', 25), ('“that', 25), ('“oh,', 25), ('bed', 25), ('shall', 25), ('“if', 25), ('can’t', 24), ('took', 24), ('three', 24), ('against', 24), ('tootles', 24), ('pirate', 24), ('another', 24), ('well', 24), ('you,', 24), ('replied', 24), ('wendy.', 24), ('seemed', 23), ('however,', 23), ('till', 23), ('again,', 23), ('terms', 23), ('except', 23), ('old', 23), ('nursery', 23), ('works', 23), ('use', 22), ('copyright', 22), ('stood', 22), ('felt', 22), ('suddenly', 22), ('tried', 22), ('again.', 22), ('here', 22), ('hook,', 22), ('until', 21), ('full', 21), ('perhaps', 21), ('“no,', 21), ('lost', 21), ('hook’s', 21), ('john,', 21), ('sa ...

# %% [markdown]
# # 3a. [20 points] Compute the TFij for each term i with j as Peter Pan

# %%
import time
time_start = time.time()

# %%
high = counts.take(1)[0][1]
TFij = counts.map(lambda x:(x[0], x[1]/high)).cache()
dbg(TFij)
# Out:
# [('the', 1.0), ('', 0.7872596153846154), ('and', 0.5677083333333334), ('to', 0.49399038461538464), ('he', 0.41225961538461536), ('a', 0.390625), ('of', 0.3870192307692308), ('was', 0.36217948717948717), ('in', 0.28725961538461536), ('it', 0.23798076923076922), ('that', 0.2327724358974359), ('she', 0.2299679487179487), ('they', 0.2263621794871795), ('had', 0.20192307692307693), ('his', 0.18870192307692307), ('you', 0.18028846153846154), ('but', 0.17708333333333334), ('for', 0.16266025641025642), ('not', 0.15865384615384615), ('her', 0.1482371794871795), ('with', 0.1482371794871795), ('is', 0.13661858974358973), ('at', 0.1346153846153846), ('as', 0.1346153846153846), ('on', 0.13421474358974358), ('i', 0.10136217948717949), ('have', 0.10056089743589744), ('be', 0.09975961538461539), ('were', 0.09735576923076923), ('peter', 0.09695512820512821), ('all', 0.09495192307692307), ('this', 0.09134615384615384), ('said', 0.08733974358974358), ('their', 0.08693910256410256), ('so', 0.08613782051282051), ('would', 0.08493589743589744), ('wendy', 0.08092948717948718), ('by', 0.0765224358974359), ('are', 0.07612179487179487), ('him', 0.07451923076923077), ('one', 0.07131410256410256), ('when', 0.06891025641025642), ('them', 0.06610576923076923), ('if', 0.0641025641025641), ('“i', 0.06370192307692307), ('there', 0.06169871794871795), ('we', 0.06169871794871795), ('no', 0.059695512820512824), ('from', 0.05889423076923077), ('or', 0.057692307692307696), ('could', 0.05568910256410257), ('been', 0.054086538461538464), ('who', 0.05368589743589743), ('which', 0.05128205128205128), ('what', 0.049679487179487176), ('did', 0.046875), ('out', 0.04607371794871795), ('up', 0.04607371794871795), ('then', 0.045272435897435896), ('do', 0.044070512820512824), ('said,', 0.04326923076923077), ('about', 0.042868589743589744), ('an', 0.04126602564102564), ('into', 0.04006410256410257), ('little', 0.03806089743589743), ('hook', 0.03766025641025641), ('darling', 0.03766025641025641), ('now', 0.037259615384615384), ('will', 0.03565705128205128), ('see', 0.035256410256410256), ('like', 0.03445512820512821), ('only', 0.03445512820512821), ('project', 0.03325320512820513), ('time', 0.03245192307692308), ('your', 0.03205128205128205), ('children', 0.03125), ('never', 0.030448717948717948), ('john', 0.030448717948717948), ('just', 0.029647435897435896), ('other', 0.029246794871794872), ('mrs.', 0.028846153846153848), ('any', 0.028846153846153848), ('cried', 0.028846153846153848), ('came', 0.02844551282051282), ('my', 0.028044871794871796), ('how', 0.028044871794871796), ('thought', 0.027644230769230768), ('must', 0.027243589743589744), ('michael', 0.027243589743589744), ('first', 0.026842948717948716), ('very', 0.026442307692307692), ('him.', 0.026442307692307692), ('know', 0.026041666666666668), ('such', 0.026041666666666668), ('it,', 0.025240384615384616), ('quite', 0.025240384615384616), ('knew', 0.025240384615384616), ('more', 0.024839743589743588), ('way', 0.024439102564102564), ('boys', 0.024439102564102564)]

# %% [markdown]
# # 3b. [10 points] Load the following 3 documents into RDDs
# ### The Adventures of Sherlock Holmes by Arthur Conan Doyle
# http://www.gutenberg.org/files/1661/1661-0.txt
# ### Alice's Adventures in Wonderland by Lewis Carroll
# http://www.gutenberg.org/files/11/11-0.txt
# ### Adventures of Huckleberry Finn by Mark Twain
# http://www.gutenberg.org/files/76/76-0.txt

# %%
# !wget -q -O SherlockHolmes.txt http://www.gutenberg.org/files/1661/1661-0.txt
# !wget -q -O Alice.txt http://www.gutenberg.org/files/11/11-0.txt
# !wget -q -O Huckleberry.txt http://www.gutenberg.org/files/76/76-0.txt

# %% [markdown]
# # 3c. [20 points] Compute IDFi for each term i over all N=4 documents in our RDDs
#
# expected output for IDF_the (the inverse document frequency of the word ‘the’) is 0 because the word ‘the’ appears in 4 out of 4 documents and log2(4 / 4) == 0
# expected output for some other words:
# [('frightfully', 2.0), ('wendy,”', 2.0), ('wendy?”', 2.0), ('peter?”', 2.0), ('nibs,', 2.0), … (‘dogs’, 0.4150374992788437)...]

# %%
from math import log2
from typing import Union

# IDFi = log2(appear in how many/total num of doc)
PeterPanWord = file.flatMap(lambda words:[(word.lower(), 1) for word in words.split(" ")]).distinct()
PeterPanCount = PeterPanWord.reduceByKey(lambda a, b:a+b).sortBy(lambda i:i[1], False).cache()

# load the file into a distributed dataset of lines
Sherlockfile = sc.textFile("SherlockHolmes.txt")
SherlockWord = Sherlockfile.flatMap(lambda words:[(word.lower(), 1) for word in words.split(" ")]).distinct()
SherlockCount = SherlockWord.reduceByKey(lambda a, b:a+b).sortBy(lambda i:i[1], False).cache()

Alicefile = sc.textFile("Alice.txt")
# print(Alicefile.collect())
AliceWord = Alicefile.flatMap(lambda words:[(word.lower(), 1) for word in words.split(" ")]).distinct()
AliceCount = AliceWord.reduceByKey(lambda a, b:a+b).sortBy(lambda i:i[1], False).cache()

Hucklefile = sc.textFile("Huckleberry.txt")
HucklekWord = Hucklefile.flatMap(lambda words:[(word.lower(), 1) for word in words.split(" ")]).distinct()
HucklekCount = HucklekWord.reduceByKey(lambda a, b:a+b).sortBy(lambda i:i[1], False).cache()

# %%
result = (PeterPanCount
        .union(SherlockCount)
        .union(AliceCount)
        .union(HucklekCount)
        .groupByKey()
        .mapValues(len)
        .map(lambda a : (a[0], log2(4/a[1])))
        .cache())
dbg(result)
result.lookup("dogs")[0]
# Out:
# [('gutenberg', 0.0), ('of', 0.0), ('james', 0.4150374992788437), ('', 0.0), ('other', 0.0), ('are', 0.0), ('check', 0.0), ('where', 0.0), ('using', 0.0), ('author:', 0.0), ('date:', 0.0), ('february', 0.4150374992788437), ('set', 0.0), ('produced', 0.0), ('research', 0.0), ('start', 0.0), ('fulcrum', 1.0), ('current', 0.0), ('publication,', 2.0), ('ii.', 0.0), ('iv.', 0.0), ('v.', 0.0), ('vii.', 0.0), ('ix.', 0.0), ('bird', 0.0), ('x.', 0.0), ('believe', 0.0), ('xvi.', 1.0), ('when', 0.0), ('one,', 0.0), ('two', 0.0), ('garden,', 0.4150374992788437), ('plucked', 1.0), ('flower', 1.0), ('i', 0.0), ('rather', 0.0), ('heart', 0.0), ('cried,', 0.4150374992788437), ('why', 0.0), ('like', 0.0), ('them', 0.0), ('but', 0.0), ('came', 0.0), ('romantic', 2.0), ('mocking', 1.0), ('boxes,', 1.0), ('however', 1.0), ('mouth', 0.0), ('corner.', 0.4150374992788437), ('he', 0.0), ('trying', 0.0), ('thought', 0.0), ('stocks', 2.0), ('really', 0.0), ('seemed', 0.0), ('would', 0.0), ('married', 0.4150374992788437), ('cauliflowers', 2.0), ('dropped', 0.0), ('babies', 2.0), ('doubtful', 1.0), ('frightfully', 2.0), ('honourable,', 2.0), ('imploringly.', 2.0), ('risk', 1.0), ('might,', 0.0), ('eight', 0.4150374992788437), ('moving?—eight', 2.0), ('you’ve', 0.4150374992788437), ('question', 0.0), ('seven?”', 2.0), ('george,”', 2.0), ('cried.', 0.0), ('mumps,”', 2.0), ('threateningly,', 2.0), ('thirty', 0.4150374992788437), ('speak—measles', 2.0), ('six—don’t', 2.0), ('shillings”—and', 2.0), ('treated', 0.0), ('excitement', 0.4150374992788437), ('michael', 0.0), ('everything', 0.0), ('passion', 1.0), ('exactly', 0.0), ('however,', 0.0), ('acquainted', 1.0), ('spare', 0.4150374992788437), ('perambulators,', 2.0), ('charges', 1.0), ('genius', 2.0), ('needs', 0.0), ('once', 0.0), ('an', 0.0), ('school', 0.0), ('difference.', 0.4150374992788437), ('social', 1.0), ('despised', 1.0), ('out', 0.0), ('yet', 0.0)]
# 0.4150374992788437

# %% [markdown]
# # 3d. [20 points] Compute TF.IDF score for each term in Peter Pan and collect/display the top 100 terms by TF.IDF score
#
# some expected output:
# [('wendy', 0.16185897435897437), ('darling', 0.07532051282051282),...

# %%
TFIDF = TFij.union(result).reduceByKey(lambda a, b: a * b).sortBy(lambda a: a[0], False).cache()
dbg(TFIDF.lookup('wendy'))
dbg(TFIDF)
# Out:
# [0.16185897435897437]
# [('“’twas', 0.0008012820512820513), ('“’tis', 2.0), ('“’s’death', 0.0008012820512820513), ('“’pon', 2.0), ('“‘—found', 2.0), ('“‘you', 2.0), ('“‘yes.’', 2.0), ('“‘yes,', 2.0), ('“‘why,’', 2.0), ('“‘why,', 2.0), ('“‘why', 2.0), ('“‘which', 2.0), ('“‘where', 2.0), ('“‘whatever', 2.0), ('“‘what,', 2.0), ('“‘what', 2.0), ('“‘well,’', 2.0), ('“‘well,', 2.0), ('“‘we', 2.0), ('“‘very', 2.0), ('“‘undoubtedly', 2.0), ('“‘tut,', 2.0), ('“‘to', 2.0), ('“‘this', 2.0), ('“‘they', 2.0), ('“‘there', 2.0), ('“‘then,', 2.0), ('“‘then', 2.0), ('“‘the', 2.0), ('“‘that’s', 2.0), ('“‘that', 2.0), ('“‘thank', 2.0), ('“‘ten', 2.0), ('“‘tell', 2.0), ('“‘surely', 2.0), ('“‘stolen!’', 2.0), ('“‘some', 2.0), ('“‘sold', 2.0), ('“‘so,’', 2.0), ('“‘she', 2.0), ('“‘see,', 0.0008012820512820513), ('“‘robert', 2.0), ('“‘quite', 2.0), ('“‘put', 2.0), ('“‘precisely.’', 2.0), ('“‘precisely', 2.0), ('“‘pooh!’', 2.0), ('“‘photography', 2.0), ('“‘perhaps', 2.0), ('“‘or', 2.0), ('“‘only', 2.0), ('“‘one', 2.0), ('“‘on', 2.0), ('“‘oh,’', 2.0), ('“‘oh,', 2.0), ('“‘oct.', 2.0), ('“‘not', 2.0), ('“‘no,’', 2.0), ('“‘no,', 2.0), ('“‘no', 2.0), ('“‘next', 2.0), ('“‘never.’', 2.0), ('“‘never,’', 2.0), ('“‘never', 2.0), ('“‘my', 2.0), ('“‘mr.', 2.0), ('“‘most', 2.0), ('“‘miss', 2.0), ('“‘may', 2.0), ('“‘mary.’', 2.0), ('“‘lord', 2.0), ('“‘look', 2.0), ('“‘ku', 2.0), ('“‘keep', 2.0), ('“‘jephro,’', 2.0), ('“‘jephro', 2.0), ('“‘it’s', 2.0), ('“‘it', 2.0), ('“‘is', 2.0), ('“‘in', 2.0), ('“‘if', 2.0), ('“‘i', 2.0), ('“‘how', 2.0), ('“‘here', 2.0), ('“‘have', 2.0), ('“‘hampshire.', 2.0), ('“‘gone', 2.0), ('“‘from', 2.0), ('“‘fritz!', 2.0), ('“‘for', 2.0), ('“‘entirely.’', 2.0), ('“‘don’t', 2.0), ('“‘do', 2.0), ('“‘december', 2.0), ('“‘death,’', 2.0), ('“‘dearest', 2.0), ('“‘dear', 2.0), ('“‘come,', 2.0), ('“‘come!', 2.0), ('“‘certainly,’', 2.0)]

# %% [markdown]
# # 3e. [10 points]
# Add overall process timing output to your code (try to include all processing but be careful not to print/collect any data except for the final top 100) to compute TF.IDF top 100 for Peter Pan:
#
# import time
#
# time_start = time.time()
# …
# print(rdd.take(100))
#
# time_end = time.time()
# print("elapsed time is %s" % str(time_end-time_start))
#
# NOTE: my reference implementation takes around 4-6 seconds including all steps

# %%
print(TFIDF.take(100))
time_end = time.time()
print("Elapsed time is %s" % str(time_end-time_start))
# Out:
# [('“’twas', 0.0008012820512820513), ('“’tis', 2.0), ('“’s’death', 0.0008012820512820513), ('“’pon', 2.0), ('“‘—found', 2.0), ('“‘you', 2.0), ('“‘yes.’', 2.0), ('“‘yes,', 2.0), ('“‘why,’', 2.0), ('“‘why,', 2.0), ('“‘why', 2.0), ('“‘which', 2.0), ('“‘where', 2.0), ('“‘whatever', 2.0), ('“‘what,', 2.0), ('“‘what', 2.0), ('“‘well,’', 2.0), ('“‘well,', 2.0), ('“‘we', 2.0), ('“‘very', 2.0), ('“‘undoubtedly', 2.0), ('“‘tut,', 2.0), ('“‘to', 2.0), ('“‘this', 2.0), ('“‘they', 2.0), ('“‘there', 2.0), ('“‘then,', 2.0), ('“‘then', 2.0), ('“‘the', 2.0), ('“‘that’s', 2.0), ('“‘that', 2.0), ('“‘thank', 2.0), ('“‘ten', 2.0), ('“‘tell', 2.0), ('“‘surely', 2.0), ('“‘stolen!’', 2.0), ('“‘some', 2.0), ('“‘sold', 2.0), ('“‘so,’', 2.0), ('“‘she', 2.0), ('“‘see,', 0.0008012820512820513), ('“‘robert', 2.0), ('“‘quite', 2.0), ('“‘put', 2.0), ('“‘precisely.’', 2.0), ('“‘precisely', 2.0), ('“‘pooh!’', 2.0), ('“‘photography', 2.0), ('“‘perhaps', 2.0), ('“‘or', 2.0), ('“‘only', 2.0), ('“‘one', 2.0), ('“‘on', 2.0), ('“‘oh,’', 2.0), ('“‘oh,', 2.0), ('“‘oct.', 2.0), ('“‘not', 2.0), ('“‘no,’', 2.0), ('“‘no,', 2.0), ('“‘no', 2.0), ('“‘next', 2.0), ('“‘never.’', 2.0), ('“‘never,’', 2.0), ('“‘never', 2.0), ('“‘my', 2.0), ('“‘mr.', 2.0), ('“‘most', 2.0), ('“‘miss', 2.0), ('“‘may', 2.0), ('“‘mary.’', 2.0), ('“‘lord', 2.0), ('“‘look', 2.0), ('“‘ku', 2.0), ('“‘keep', 2.0), ('“‘jephro,’', 2.0), ('“‘jephro', 2.0), ('“‘it’s', 2.0), ('“‘it', 2.0), ('“‘is', 2.0), ('“‘in', 2.0), ('“‘if', 2.0), ('“‘i', 2.0), ('“‘how', 2.0), ('“‘here', 2.0), ('“‘have', 2.0), ('“‘hampshire.', 2.0), ('“‘gone', 2.0), ('“‘from', 2.0), ('“‘fritz!', 2.0), ('“‘for', 2.0), ('“‘entirely.’', 2.0), ('“‘don’t', 2.0), ('“‘do', 2.0), ('“‘december', 2.0), ('“‘death,’', 2.0), ('“‘dearest', 2.0), ('“‘dear', 2.0), ('“‘come,', 2.0), ('“‘come!', 2.0), ('“‘certainly,’', 2.0)]
# Elapsed time is 8.897184371948242
